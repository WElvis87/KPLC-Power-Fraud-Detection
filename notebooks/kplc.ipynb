# %%
import pandas as pd

# %%
kplc = pd.read_csv("../data/kplc.csv")

# %%
kplc
# Out:
#        household_id household_type   region       month  consumption_kWh  \
# 0                 0            low  Eldoret  2022-01-01        65.057809
# 1                 0            low  Eldoret  2022-02-01        64.967802
# 2                 0            low  Eldoret  2022-03-01        62.733026
# 3                 0            low  Eldoret  2022-04-01        57.824316
# 4                 0            low  Eldoret  2022-05-01        59.342724
# ...             ...            ...      ...         ...              ...
# 71995          1999            low  Malindi  2024-08-01        47.256463
# 71996          1999            low  Malindi  2024-09-01        45.043167
# 71997          1999            low  Malindi  2024-10-01        42.888163
# 71998          1999            low  Malindi  2024-11-01        56.989555
# 71999          1999            low  Malindi  2024-12-01        41.493986
#
#        temperature    rainfall  theft_flag  prev_month_consumption  \
# ...

# %%
kplc["region"].unique().tolist()
# Out:
# ['Eldoret',
#  'Mombasa',
#  'Kisumu',
#  'Nakuru',
#  'Malindi',
#  'Nairobi',
#  'Nyeri',
#  'Thika']

# %%
kplc.dtypes
# Out:
# household_id                int64
# household_type             object
# region                     object
# month                      object
# consumption_kWh           float64
# temperature               float64
# rainfall                  float64
# theft_flag                  int64
# prev_month_consumption    float64
# consumption_diff          float64
# 3m_avg                    float64
# 6m_avg                    float64
# dtype: object

# %%
kplc["theft_flag"].dtypes
# Out:
# dtype('int64')
